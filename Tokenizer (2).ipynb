# %%
pip install transformers

# %%
from transformers import GPT2TokenizerFast
from transformers.utils.hub import cached_file

# %%
tokenizer = GPT2TokenizerFast.from_pretrained("gpt2")

# %%
vocab_file_path= cached_file("gpt2","vocab.json")
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]

# %%
# !cat "{vocab_file_path}"

# %%
merge_file_path= cached_file("gpt2","merges.txt")

# %%
# !cat "{merge_file_path}"

# %%
from tokenizers import Tokenizer
from tokenizers.models import BPE
from tokenizers.trainers import BpeTrainer
from tokenizers.pre_tokenizers import Whitespace

# %%
tokenizer = Tokenizer(BPE(unk_token="[UNK]"))
tokenizer.pre_tokenizer =Whitespace()

# %%
trainer =BpeTrainer(vocab_size = 1000)

# %%
word = "I am Sachin. Artificial Intelligence and Machine Learning Student"
with open("word.txt", "w") as f:
    f.write(word)

# %%
tokenizer.train(["word.txt"], trainer)

# %%
tokenizer.save("MY_tokenizer.json")

# %%
# !cat "MY_tokenizer.json"
# Out:
# {
#   "version": "1.0",
#   "truncation": null,
#   "padding": null,
#   "added_tokens": [],
#   "normalizer": null,
#   "pre_tokenizer": {
#     "type": "Whitespace"
#   },
#   "post_processor": null,
#   "decoder": null,
#   "model": {
#     "type": "BPE",
#     "dropout": null,
#     "unk_token": "[UNK]",
#     "continuing_subword_prefix": null,
#     "end_of_word_suffix": null,
#     "fuse_unk": false,
#     "byte_fallback": false,
#     "ignore_merges": false,
#     "vocab": {
#       ".": 0,
#       "A": 1,
#       "I": 2,
#       "L": 3,
#       "M": 4,
#       "S": 5,
#       "a": 6,
#       "c": 7,
#       "d": 8,
#       "e": 9,
#       "f": 10,
#       "g": 11,
#       "h": 12,
#       "i": 13,
#       "l": 14,
#       "m": 15,
#       "n": 16,
#       "r": 17,
#       "t": 18,
#       "u": 19,
#       "in": 20,
#       "ac": 21,
#       "en": 22,
#       "hin": 23,
#       "achin": 24,
#       "Ar": 25,
#       "In": 26,
#       "Le": 27,
#       "Machin": 28,
# ...
